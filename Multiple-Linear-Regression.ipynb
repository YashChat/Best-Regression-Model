# %% [markdown]
# # Now we will run different regression models

# %% [markdown]
# ## 1) Multiple Linear Regression

# %% [markdown]
# ## Check for Assumptions -
# ### Linearity - This assumes that there is a linear relationship between the predictors (e.g. independent variables or features) and the response variable (e.g. dependent variable or label). This also assumes that the predictors are additive.
# ### Why it can happen - There may not just be a linear relationship among the data. Modeling is about trying to estimate a function that explains a process, and linear regression would not be a fitting estimator (pun intended) if there is no linear relationship.
# ### How to fix it: Either adding polynomial terms to some of the predictors or applying nonlinear transformations . If those do not work, try adding additional variables to help capture the relationship between the predictors and the label.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
sns.set(context="notebook", palette="Spectral", style = 'darkgrid' ,font_scale = 1.5, color_codes=True)

# %%
non_correlated_data = pd.read_csv('removed_correlations.csv')
non_correlated_data = non_correlated_data.drop(['Unnamed: 0'], axis=1)
non_correlated_data.head()
# Out:
#      0    1    2           3           5           6
# 0  1.0  1.0  0.0  341.120176   95.554853   75.181807
# 1  0.0  0.0  0.0  118.610087   66.456064   93.011581
# 2  1.0  1.0  0.0   77.254576   40.766024   -1.588632
# 3  1.0  0.0  1.0  476.980523  144.335903  512.778893
# 4  1.0  0.0  1.0  258.225846  144.487597  364.063824

# %%
non_correlated_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2550 entries, 0 to 2549
# Data columns (total 6 columns):
# 0    2550 non-null float64
# 1    2550 non-null float64
# 2    2550 non-null float64
# 3    2550 non-null float64
# 5    2550 non-null float64
# 6    2550 non-null float64
# dtypes: float64(6)
# memory usage: 119.6 KB

# %%
non_correlated_data.describe()
# Out:
#                  0            1            2            3            5  \
# count  2550.000000  2550.000000  2550.000000  2550.000000  2550.000000
# mean      0.492941     0.507059     0.508235   252.348506    89.852496
# std       0.500048     0.500048     0.500030   146.556638    35.302143
# min       0.000000     0.000000     0.000000     0.050706    29.013959
# 25%       0.000000     0.000000     0.000000   128.646969    59.582918
# 50%       0.000000     1.000000     1.000000   248.703167    89.919219
# 75%       1.000000     1.000000     1.000000   380.425920   119.406005
# max       1.000000     1.000000     1.000000   511.547524   151.990754
#
#                  6
# count  2550.000000
# mean    175.961880
# std     125.695888
# min    -113.121946
# 25%      85.310735
# 50%     159.972378
# 75%     256.186915
# max     545.342187

# %%
p = sns.pairplot(non_correlated_data)

# %%
# visualize the relationship between the features and the response using scatterplots
p = sns.pairplot(non_correlated_data, x_vars=['0','1','2','3','5'], y_vars='6', size=7, aspect=0.7)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## A linear model might not be able to efficiently explain the data in terms of variability, prediction accuracy etc, as we can see the relation between column '5' and column '6' is not linear.
